# %%
print("i love python ")
# Out:
# i love python

# %%
print("india is a beautiful land")
# Out:
# india is a beautiful land

# %%
a=2
b=0.4
c=True 
d="trishula"

# %%
#python do Dynamic tying 
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# bool

# %%
type(d)
# Out:
# str

# %%
a=2
b=5
print("Addition of two numbers is",a+b)
# Out:
# Addition of two numbers is 7

# %%
a=3
b=9
print("Subtraction of two numbers is",a-b)
# Out:
# Subtraction of two numbers is -6

# %%
a=9
b=3
print("subtraction of two numbers is",a-b)
# Out:
# subtraction of two numbers is 6

# %%
c=5
d=6
print("multiplication of two numbers is",c*d)
# Out:
# multiplication of two numbers is 30

# %%
c=10
d=5
print("division of two numbers is",c/d)
# Out:
# division of two numbers is 2.0

# %%
#input was giving us strings there we have converted it into "int"
#typecasting #explicit typecasting
a=int(input("Enter the first numburs"))
b=int(input("Enter the second numbers"))
print("Additional of two numbers is",a+b)
print("Subtraction of two numbers is",a-b)
print("Multiplication of two numbers is",a*b)
print("Division of two numbers is",a/b)
# Out:
# Enter the first numburs 10
# Enter the second numbers 20
# Additional of two numbers is 30
# Subtraction of two numbers is -10
# Multiplication of two numbers is 200
# Division of two numbers is 0.5

# %%
#f-string 
a=3
b=4
print(f"addition of two numbers{a}and {b}is{a+b}")
# Out:
# addition of two numbers3and 4is7

# %%
#here u need to print the output as text\strings so no need of "int" function 
#(after input.
first_name=input("enter the first name of the guest")
last_name=input("enter the last name of the guest")
print(f"Hello,{first_name}{last_name},Welcome to my humble abode")
# Out:
# enter the first name of the guest Trishula
# enter the last name of the guest Mitra
# Hello,TrishulaMitra,Welcome to my humble abode

# %%
#implicit typecasting
aa=27

# %%
type(aa)
# Out:
# int

# %%
aa=aa+0.1

# %%
type(aa)
# Out:
# float

# %%
#modular operator (%)
#it returns the remainder of a division problem
#mod of even numbers are 0 #mod of odd numbers are 1
# to write condition if(a%2==0 {it is the condition : then the expression,else: expression
#== equality operator, it checks if both side is equal or not
#indettation
#whether the number is even or odd

n=int(input("Enter the number"))
if(n%2==0):
    print("number is even")
else:
    print("number is odd")
# Out:
# Enter the number 12
# number is even
